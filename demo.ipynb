# %%
# %pip install requirements.txt

# %%
import os

current_dir = os.getcwd()
print(current_dir)

os.chdir('./BIAS')
print('changed working dir:-> ', os.getcwd())
# Out:
# D:\workingDocuments\LYTLab\codes\BIAS
# changed working dir:->  D:\workingDocuments\LYTLab\codes\BIAS\BIAS

# %%
# !python main.py --video_path ../example_data/demo.AVI --generate_name ../demo_rst.mp4 
# the program may take ~40 seconds to run...
# Out:
# Done!
# ...
# 100%|█████████▉| 782/783 [00:40<00:00, 19.14it/s]
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
