# %%
import os

current_dir = os.getcwd()
print(current_dir)

os.chdir('./BIAS')
print('changed working dir:-> ', os.getcwd())
# Out:
# d:\workingDocuments\LYTLab\codes\BioinspiredRtSaliency
# changed working dir:->  d:\workingDocuments\LYTLab\codes\BioinspiredRtSaliency\src

# %%
# !python main.py --video_path ../example_data/002.AVI --generate_name ../example_data/002_rst.mp4 
# the result may take ~40 seconds...
# Out:
# Done!
# ...
# 100%|█████████▉| 782/783 [00:41<00:00, 19.06it/s]
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
